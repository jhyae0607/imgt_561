# %%
import pandas as pd
import numpy as np
import os
import pickle

# %%
def load_data(filepath):
    # load list of json files
    with open(filepath, 'rb') as file:
        metadata_lst = pickle.load(file)

    return metadata_lst

# %%
csv = load_data('./saved_df/email_df')

# %%
csv
# Out:
#                                               file
# 427616                     shackleton-s/sent/1912.  \
# 108773                    farmer-d/logistics/1066.
# 355471                  parks-j/deleted_items/202.
# 457837  stokley-c/chris_stokley/iso/client_rep/41.
# 124910               germany-c/all_documents/1174.
# 403283                     scott-s/_sent_mail/244.
# 293966              love-p/discussion_threads/113.
# 478830               taylor-m/australia_trading/8.
# 295428                      love-p/sent_items/765.
# 137822                  giron-d/deleted_items/170.
#
#                                                   message
# 427616  Message-ID: <21013688.1075844564560.JavaMail.e...
# 108773  Message-ID: <22688499.1075854130303.JavaMail.e...
# 355471  Message-ID: <27817771.1075841359502.JavaMail.e...
# 457837  Message-ID: <10695160.1075858510449.JavaMail.e...
# 124910  Message-ID: <27819143.1075853689038.JavaMail.e...
# 403283  Message-ID: <10142547.1075846737160.JavaMail.e...
# 293966  Message-ID: <18212904.1075858229814.JavaMail.e...
# 478830  Message-ID: <14840674.1075860237113.JavaMail.e...
# 295428  Message-ID: <22170097.1075862178026.JavaMail.e...
# 137822  Message-ID: <23520008.1075852220995.JavaMail.e...

# %%
filepath_metadata = './saved_metadata/metadata_lst'
filepath_usrdata = './saved_metadata/usr_info.csv'

metadata_lst = load_data(filepath_metadata)

# %%
# convert list of string jsons to dataframe
import json

metadata_cols = ['MessageID', 'Date', 'From', 'To', 'Cc', 'Bcc', 'Subject', 'MimeVersion',
                 'ContentType', 'ContentTransferEncoding', 'Summarized Content', 'Attachments' ]

metadata_df = pd.DataFrame(columns=metadata_cols)

for element in metadata_lst:
    metadata_json = json.loads(element)
    new_row = pd.DataFrame([metadata_json])
    metadata_df = pd.concat([metadata_df, new_row], ignore_index=True)

# %%
# Standardize date/time to EST
import datetime

datetime_lst = []

for date in metadata_df['Date']:
    # modify date to "%Y-%m-%d %H:%M:%S" format
    input_datetime = str(date)
    input_datetime = input_datetime[:-12]
    dt_object = datetime.datetime.strptime(input_datetime, "%a, %d %b %Y %H:%M:%S")
    output_datetime = dt_object.strftime("%Y-%m-%d %H:%M:%S")
    output_datetime = datetime.datetime.strptime(output_datetime, "%Y-%m-%d %H:%M:%S")

    # convert from pst to est
    time_diff = datetime.timedelta(hours=3)
    est_datetime = output_datetime - time_diff
    est_datetime = est_datetime.strftime("%Y-%m-%d %H:%M:%S")
    
    # append to date_lst
    datetime_lst.append(est_datetime)

# replace date with modified datetime format
metadata_df['Date'] = datetime_lst

# %%
# replace null or [] values with None
import re
metadata_df.replace([''], 'None', inplace=True)
metadata_df = metadata_df.applymap(lambda x: re.sub(r'^\[\s*\]$', 'None', str(x)))

# %%
# Load Logics
import sqlite3

# Create sqlite3 tables from dataframe
database_file_path = './email.db'
with sqlite3.connect(database_file_path) as conn:
    cur = conn.cursor()
    metadata_df.to_sql('Email', conn, if_exists='replace', index=False)
    conn.commit()
    print('Dataframe converted to table!')

# Add indexes after data is added
# Out:
# Dataframe converted to table!
# Insert command successful!

# %%
# Insert the metadata_df
with sqlite3.connect(database_file_path) as conn:
    cur = conn.cursor()
    cur.execute('''
        INSERT INTO Email (MessageID, Date, "From", "To", Cc, Bcc, Subject, MimeVersion, ContentType, ContentTransferEncoding, "Summarized Content", Attachments)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    ''', (metadata_df.iloc[2]))
    
    conn.commit()
    print('Insert command successful!')
# Out:
# Insert command successful!

# %%
metadata_df
# Out:
#                                        MessageID                 Date
# 0  <21013688.1075844564560.JavaMail.evans@thyme>  2000-08-28 22:26:00  \
# 1  <22688499.1075854130303.JavaMail.evans@thyme>  2000-04-24 02:43:00
# 2  <27817771.1075841359502.JavaMail.evans@thyme>  2002-05-02 01:54:27
# 3  <10695160.1075858510449.JavaMail.evans@thyme>  2001-08-08 11:35:08
# 4  <27819143.1075853689038.JavaMail.evans@thyme>  2000-06-21 01:58:00
# 5  <10142547.1075846737160.JavaMail.evans@thyme>  2000-05-10 08:22:00
# 6  <18212904.1075858229814.JavaMail.evans@thyme>  2000-06-07 08:30:00
# 7  <14840674.1075860237113.JavaMail.evans@thyme>  2000-04-12 23:42:00
# 8  <22170097.1075862178026.JavaMail.evans@thyme>  2001-11-09 10:36:17
# 9  <23520008.1075852220995.JavaMail.evans@thyme>  2001-10-15 12:11:42
#
#                          From
# 0   sara.shackleton@enron.com  \
# 1        pat.clynes@enron.com
# 2              knipe3@msn.com
# 3          kalmeida@caiso.com
# 4     chris.germany@enron.com
# 5       susan.scott@enron.com
# 6      phillip.love@enron.com
# 7  cynthia.harkness@enron.com
# 8           m..love@enron.com
# 9        orderdetails@buy.com
#
#                                                   To                      Cc
# 0                         william.bradford@enron.com                    None  \
# 1                             aimee.lannou@enron.com  daren.farmer@enron.com
# 2  fenner.chet@enron.com, joe.parks@enron.com, co...                    None
# 3                            chris.stokley@enron.com                    None
# 4                             thomas.engel@enron.com                    None
# 5                               david.foti@enron.com    rich.jolly@enron.com
# 6                            delma.salazar@enron.com                    None
# 7                              mark.taylor@enron.com                    None
# 8                             stevebonilla@yahoo.com                    None
# 9                                   dgiron@enron.com                    None
#
#                       Bcc                              Subject MimeVersion
# 0                    None               Re: Credit Derivatives         1.0  \
# 1  daren.farmer@enron.com            Meter #1591 Lamay Gaslift         1.0
# 2                    None                 Re: man night again?         1.0
# 3                    None              Enron 480, 1480 charges         1.0
# 4                    None                       Transport Deal         1.0
# 5    rich.jolly@enron.com  Re: WT-1 Electric Service Agreement         1.0
# 6                    None        0003-0001 OAs as of 4/2000 GL         1.0
# 7                    None                            Leona Tan         1.0
# 8                    None                            RE: Hello         1.0
# 9                    None     Your buy.com order is on its way         1.0
#
#                     ContentType ContentTransferEncoding
# 0  text/plain; charset=us-ascii                    7bit  \
# 1  text/plain; charset=us-ascii                    7bit
# 2  text/plain; charset=us-ascii                    7bit
# 3  text/plain; charset=us-ascii                    7bit
# 4  text/plain; charset=us-ascii                    7bit
# 5  text/plain; charset=us-ascii                    7bit
# 6  text/plain; charset=us-ascii                    7bit
# 7  text/plain; charset=us-ascii                    7bit
# 8  text/plain; charset=us-ascii                    7bit
# 9  text/plain; charset=us-ascii                    7bit
#
#                                   Summarized Content         Attachments
# 0  Sara asks for clarification on EnronCredit.com...                None
# 1  Please check meter #1591 Lamay gas lift.  It d...                None
# 2  GCCA Crawfish and rip-off raffle & over-priced...                None
# 3  Chris, per your request here are the 480 and 1...       ['Keoni.zip']
# 4  Chris Germany is trying to change the Receipt ...                None
# 5  Susan Scott suggests replacing Section 2 and 3...                None
# 6  Forwarded email regarding 0003-0001 OAs as of ...                None
# 7  Attached is Leona Tan's resume. Please let me ...  Leona Tan's resume
# 8  got your message last night.  What is up?  Bet...                None
# 9  The email is a notification that items from or...                None

# %%
# SQL logics

# Insert

# Update

# Delete

# Single Select 

# Select Many
